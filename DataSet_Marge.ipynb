# %%
import pandas as pd
import re
import nltk
import numpy as np

# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Jannatul
# [nltk_data]     Mawya\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Jannatul Mawya\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
cyberbullying_tweets=df=pd.read_csv(r"C:\Users\Jannatul Mawya\OneDrive\Pictures\Cyberbullying Thesis\cyberbullying_tweets.csv")
aggression_parsed_dataset=df=pd.read_csv(r"C:\Users\Jannatul Mawya\OneDrive\Pictures\Cyberbullying Thesis\aggression_parsed_dataset.csv")
cb_multi_labeled_balanced_dataset=df=pd.read_csv(r"C:\Users\Jannatul Mawya\OneDrive\Pictures\Cyberbullying Thesis\cb_multi_labeled_balanced_dataset.csv")
Cyberbullydata=df=pd.read_csv(r"C:\Users\Jannatul Mawya\OneDrive\Pictures\Cyberbullying Thesis\Cyberbullydata.csv")
CyberBullying_Comments_Dataset=df=pd.read_csv(r"C:\Users\Jannatul Mawya\OneDrive\Pictures\Cyberbullying Thesis\CyberBullying_Comments_Dataset.csv")

# %%
cb_tweets=pd.read_csv(r"C:\Users\Jannatul Mawya\OneDrive\Pictures\Cyberbullying Thesis\cyberbullying_tweets.csv")
aggression=pd.read_csv(r"C:\Users\Jannatul Mawya\OneDrive\Pictures\Cyberbullying Thesis\aggression_parsed_dataset.csv")
cb_multi=pd.read_csv(r"C:\Users\Jannatul Mawya\OneDrive\Pictures\Cyberbullying Thesis\cb_multi_labeled_balanced_dataset.csv")
cb_data=pd.read_csv(r"C:\Users\Jannatul Mawya\OneDrive\Pictures\Cyberbullying Thesis\Cyberbullydata.csv")
cb_Comments=pd.read_csv(r"C:\Users\Jannatul Mawya\OneDrive\Pictures\Cyberbullying Thesis\CyberBullying_Comments_Dataset.csv")

# %%
print("cyberbullying_tweets:",cb_tweets.columns)
print("aggression_parsed_dataset:",aggression.columns)
print("cb_multi_labeled_balanced_dataset",cb_multi.columns)
print("Cyberbullydata:", cb_data.columns)
print("CyberBullying_Comments_Dataset",cb_Comments.columns)
# Out:
# cyberbullying_tweets: Index(['tweet_text', 'cyberbullying_type'], dtype='object')
# aggression_parsed_dataset: Index(['index', 'Text', 'ed_label_0', 'ed_label_1', 'oh_label'], dtype='object')
# cb_multi_labeled_balanced_dataset Index(['text', 'label'], dtype='object')
# Cyberbullydata: Index(['index', 'Text', 'ed_label_0', 'ed_label_1', 'oh_label'], dtype='object')
# CyberBullying_Comments_Dataset Index(['Text', 'CB_Label'], dtype='object')

# %%
print("cyberbullying_tweets:",cb_tweets['cyberbullying_type'].unique())
print("aggression_parsed_dataset:",aggression['oh_label'].unique())
print("cb_multi_labeled_balanced_dataset",cb_multi['label'].unique())
print("Cyberbullydata:", cb_data ['oh_label'].unique())
print("CyberBullying_Comments_Dataset",cb_Comments['CB_Label'].unique())
# Out:
# cyberbullying_tweets: ['not_cyberbullying' 'gender' 'religion' 'other_cyberbullying' 'age'
#  'ethnicity']
# aggression_parsed_dataset: [0 1]
# cb_multi_labeled_balanced_dataset ['ethnicity/race' 'not_cyberbullying' 'religion' 'gender/sexual']
# Cyberbullydata: [0 1]
# CyberBullying_Comments_Dataset [0 1]

# %%
print("cyberbullying_tweets:",cb_tweets.shape)
print("aggression_parsed_dataset:",aggression.shape)
print("cb_multi_labeled_balanced_dataset",cb_multi.shape)
print("Cyberbullydata:", cb_data.shape)
print("CyberBullying_Comments_Dataset",cb_Comments.shape)
# Out:
# cyberbullying_tweets: (47692, 2)
# aggression_parsed_dataset: (115864, 5)
# cb_multi_labeled_balanced_dataset (99990, 2)
# Cyberbullydata: (20083, 5)
# CyberBullying_Comments_Dataset (11100, 2)

# %%
cb_tweets['label']=cb_tweets['cyberbullying_type'].apply(
    lambda x: 0 if x=='not_cyberbullying' else 1
) #RENAME
#we need thsi two column #UNnecessary column is deleted
cb_tweets = cb_tweets[['tweet_text', 'label']]
cb_tweets.columns = ['text', 'label']

#---aggression---
aggression=aggression[['Text','oh_label']]
aggression.columns=['text','label']
#cb_tweets


#---cb_multi----
cb_multi['label']=cb_multi['label'].apply(
    lambda x: 0 if x=='not_cyberbullying' else 1
)
cb_multi=cb_multi[['text','label']]


#---cb_data---
cb_data=cb_data[['Text','oh_label']]
cb_data.columns=['text','label']

#---cb_comments---
cb_Comments=cb_Comments[['Text', 'CB_Label']]
cb_Comments.columns=['text','label']

# %%
final_df=pd.concat([
    cb_tweets,
    aggression,
    cb_data,
    cb_multi,
    cb_comments], axis=0)
df=final_df.sample(frac=1).reset_index(drop=True)
print('columns:', df.columns)
print('shape:', df.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[127], line 6
#       1 final_df=pd.concat([
#       2     cb_tweets,
#       3     aggression,
#       4     cb_data,
#       5     cb_multi,
# ----> 6     cb_comments], axis=0)
#       7 df=final_df.sample(frac=1).reset_index(drop=True)
#       8 print('columns:', df.columns)
#
# NameError: name 'cb_comments' is not defined
